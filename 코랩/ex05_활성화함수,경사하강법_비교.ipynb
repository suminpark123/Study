# %% [markdown]
# 1. 활성화함수 : sigmoid,경사하강법:SGD
# 2. 활성화함수 : relu,경사하강법:SGD
# 3. 활성화함수 : relu,경사하강법:Adam

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# %%
(X_train,y_train),(X_test,y_test)=fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import InputLayer,Dense,Flatten
from tensorflow.keras.optimizers import SGD,Adam
#최적의 도구의 속성을 조절하기 위해 클래스 가져오기

# %%
# 1. 활성화 함수 : sigmoid, 경사하강법 : SGD
model1 = Sequential()
model1.add(InputLayer(input_shape=(28,28)))
model1.add(Flatten())
model1.add(Dense(units=128,activation='sigmoid'))
model1.add(Dense(units=256,activation='sigmoid'))
model1.add(Dense(units=128,activation='sigmoid'))
model1.add(Dense(units=64,activation='sigmoid'))
model1.add(Dense(units=10,activation='sigmoid'))

model1.compile(loss='sparse_categorical_crossentropy',
               optimizer=SGD(lr=0.01), #lr : 학습률
               metrics=['accuracy'])

model1_history  = model1.fit(X_test,y_train,validation_split=0.3,
                             epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 219/219 [==============================] - 2s 7ms/step - loss: 2.3356 - accuracy: 0.0993 - val_loss: 2.3065 - val_accuracy: 0.0910
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3035 - accuracy: 0.1077 - val_loss: 2.3044 - val_accuracy: 0.1020
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3037 - accuracy: 0.1021 - val_loss: 2.3044 - val_accuracy: 0.0913
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3037 - accuracy: 0.1061 - val_loss: 2.3048 - val_accuracy: 0.1030
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3029 - accuracy: 0.1061 - val_loss: 2.3047 - val_accuracy: 0.0997
# Epoch 6/100
# ...

# %%
model2 = Sequential()
model2.add(InputLayer(input_shape=(28,28)))
model2.add(Flatten())
model2.add(Dense(units=128,activation='sigmoid'))
model2.add(Dense(units=256,activation='relu'))
model2.add(Dense(units=128,activation='relu'))
model2.add(Dense(units=64,activation='relu'))
model2.add(Dense(units=10,activation='softmax'))

model2.compile(loss='sparse_categorical_crossentropy',
               optimizer=SGD(lr=0.01), #lr : 학습률
               metrics=['accuracy'])

model2_history  = model2.fit(X_test,y_train,validation_split=0.3,
                             epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3122 - accuracy: 0.1020 - val_loss: 2.3064 - val_accuracy: 0.1060
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3039 - accuracy: 0.1083 - val_loss: 2.3068 - val_accuracy: 0.1053
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3018 - accuracy: 0.1099 - val_loss: 2.3053 - val_accuracy: 0.1000
# Epoch 4/100
# 219/219 [==============================] - 1s 2ms/step - loss: 2.3001 - accuracy: 0.1120 - val_loss: 2.3081 - val_accuracy: 0.0960
# Epoch 5/100
# 219/219 [==============================] - 1s 2ms/step - loss: 2.2995 - accuracy: 0.1161 - val_loss: 2.3092 - val_accuracy: 0.0930
# Epoch 6/100
# ...

# %%
model3 = Sequential()
model3.add(InputLayer(input_shape=(28,28)))
model3.add(Flatten())
model3.add(Dense(units=128,activation='relu'))
model3.add(Dense(units=256,activation='relu'))
model3.add(Dense(units=128,activation='relu'))
model3.add(Dense(units=64,activation='relu'))
model3.add(Dense(units=10,activation='softmax'))

model3.compile(loss='sparse_categorical_crossentropy',
               optimizer=Adam(lr=0.01), #lr : 학습률
               metrics=['accuracy'])

model3_history  = model3.fit(X_test,y_train,validation_split=0.3,
                             epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 219/219 [==============================] - 1s 4ms/step - loss: 13.6299 - accuracy: 0.1083 - val_loss: 2.3038 - val_accuracy: 0.0907
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3029 - accuracy: 0.1047 - val_loss: 2.3045 - val_accuracy: 0.0910
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3029 - accuracy: 0.1086 - val_loss: 2.3031 - val_accuracy: 0.1010
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3034 - accuracy: 0.1026 - val_loss: 2.3039 - val_accuracy: 0.0907
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3035 - accuracy: 0.1060 - val_loss: 2.3042 - val_accuracy: 0.1017
# Epoch 6/100
# ...

# %%
plt.figure(figsize=(15,5))
# sigmoid+SGD
plt.plot(model1_history.history['accuracy'],label='sigmoid_SGD')
plt.plot(model1_history.history['val_accuracy'], label='val_sigmoid_SGD')
#relu+SGD
plt.plot(model2_history.history['accuracy'],label='relu_SGD')
plt.plot(model2_history.history['val_accuracy'], label='val_relu_SGD')
#relu+Adam
plt.plot(model3_history.history['accuracy'],label='relu_Adam')
plt.plot(model3_history.history['val_accuracy'], label='val_relu_Adam')
plt.legend()    #범례
plt.show()
